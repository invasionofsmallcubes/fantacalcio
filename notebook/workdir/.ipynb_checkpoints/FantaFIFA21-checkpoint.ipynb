# %%
import pandas as pd

# %%
def convertAndSum(x):
    listOfStrings = x.split('+')
    lst = [int(i) if i != '' else 0 for i in listOfStrings]
    return sum(lst)

# %%
data = pd.read_csv (r'players_21.csv')

# %%
data.dropna(subset = ["league_name"], inplace=True)

# %%
data.drop(columns=['id', 'value_eur','nation_jersey_number','contract_valid_until', 'nation_position','loaned_from','joined','team_position','work_rate','work_rate', 'wage_eur', 'international_reputation','player_url', 'age', 'club_name', 'nationality','release_clause_eur','team_jersey_number', 'long_name', 'date_of_birth', 'height_cm', 'weight_kg', 'league_name', 'league_rank', 'body_type', 'real_face'], inplace=True)

# %%
data['ldm'] = data['ldm'].apply(lambda x: convertAndSum(x))
data['cdm'] = data['cdm'].apply(lambda x: convertAndSum(x))
data['rdm'] = data['rdm'].apply(lambda x: convertAndSum(x))
data['rwb'] = data['rwb'].apply(lambda x: convertAndSum(x))
data['lb'] = data['lb'].apply(lambda x: convertAndSum(x))
data['lcb'] = data['lcb'].apply(lambda x: convertAndSum(x))
data['cb'] = data['cb'].apply(lambda x: convertAndSum(x))
data['rcb'] = data['rcb'].apply(lambda x: convertAndSum(x))
data['rb'] = data['rb'].apply(lambda x: convertAndSum(x))
data['ls'] = data['ls'].apply(lambda x: convertAndSum(x))
data['st'] = data['st'].apply(lambda x: convertAndSum(x))
data['rs'] = data['rs'].apply(lambda x: convertAndSum(x))
data['lw'] = data['lw'].apply(lambda x: convertAndSum(x))
data['lf'] = data['lf'].apply(lambda x: convertAndSum(x))
data['cf'] = data['cf'].apply(lambda x: convertAndSum(x))
data['rf'] = data['rf'].apply(lambda x: convertAndSum(x))
data['rw'] = data['rw'].apply(lambda x: convertAndSum(x))
data['lam'] = data['lam'].apply(lambda x: convertAndSum(x))
data['cam'] = data['cam'].apply(lambda x: convertAndSum(x))
data['ram'] = data['ram'].apply(lambda x: convertAndSum(x))
data['lm'] = data['lm'].apply(lambda x: convertAndSum(x))
data['lcm'] = data['lcm'].apply(lambda x: convertAndSum(x))
data['cm'] = data['cm'].apply(lambda x: convertAndSum(x))
data['rcm'] = data['rcm'].apply(lambda x: convertAndSum(x))
data['rm'] = data['rm'].apply(lambda x: convertAndSum(x))
data['lwb'] = data['lwb'].apply(lambda x: convertAndSum(x))

# %%
data[data.player_positions.str.contains("ST")].sort_values(by=['shooting', 'physic'], ascending=False)
# Out:
#               short_name  overall  potential player_positions preferred_foot  \
# 1      Cristiano Ronaldo     92.0       92.0           ST, LW          Right
# 43           C. Immobile     87.0       87.0               ST          Right
# 168       Z. Ibrahimović     83.0       83.0               ST          Right
# 136            J. Iličić     84.0       84.0           CF, ST           Left
# 299             A. Milik     81.0       84.0               ST           Left
# ...                  ...      ...        ...              ...            ...
# 15563           V. Pinto     59.0       74.0               ST          Right
# 15535        G. Cangiano     59.0       75.0           LW, ST          Right
# 16878            S. Coly     57.0       67.0               ST          Right
# 16247        Z. Ruggiero     58.0       71.0           CF, ST          Right
# 13904         V. Millico     61.0       79.0           LW, ST          Right
#
#        weak_foot  skill_moves  \
# 1            4.0          5.0
# 43           4.0          3.0
# 168          4.0          5.0
# 136          4.0          4.0
# 299          3.0          4.0
# ...          ...          ...
# 15563        3.0          2.0
# 15535        3.0          2.0
# 16878        2.0          2.0
# 16247        3.0          2.0
# 13904        3.0          3.0
#
#                                              player_tags  pace  shooting  ...  \
# 1      #Aerial Threat, #Dribbler, #Distance Shooter, ...  89.0      93.0  ...
# 43                                    #Clinical Finisher  84.0      88.0  ...
# 168    #Poacher, #Aerial Threat, #Distance Shooter, #...  52.0      88.0  ...
# 136                                    #Distance Shooter  70.0      86.0  ...
# 299                         #Poacher, #Clinical Finisher  68.0      85.0  ...
# ...                                                  ...   ...       ...  ...
# 15563                                                NaN  64.0      57.0  ...
# 15535                                                NaN  67.0      56.0  ...
# 16878                                                NaN  69.0      55.0  ...
# 16247                                                NaN  64.0      55.0  ...
# 13904                                                NaN  54.0      55.0  ...
#
#        lwb  ldm  cdm  rdm  rwb  lb  lcb  cb  rcb  rb
# 1       68   64   64   64   68  64   57  57   57  64
# 43      64   63   63   63   64  62   59  59   59  62
# 168     56   61   61   61   56  53   55  55   55  53
# 136     67   67   67   67   67  62   56  56   56  62
# 299     59   59   59   59   59  57   56  56   56  57
# ...    ...  ...  ...  ...  ...  ..  ...  ..  ...  ..
# 15563   38   37   37   37   38  37   37  37   37  37
# 15535   48   44   44   44   48  45   39  39   39  45
# 16878   41   37   37   37   41  40   37  37   37  40
# 16247   47   44   44   44   47  44   36  36   36  44
# 13904   48   44   44   44   48  45   39  39   39  45
#
# [107 rows x 81 columns]

# %%
for col in data.columns:
    print(col)
# Out:
# short_name
# overall
# potential
# player_positions
# preferred_foot
# weak_foot
# skill_moves
# player_tags
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb
